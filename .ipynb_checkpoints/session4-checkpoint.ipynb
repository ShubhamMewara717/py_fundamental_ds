# %%
#find the length of a gives string without using the len() function
s = input('enter the string')

counter = 0
for i in s:
    counter +=1
print("length of string is",counter)
# Out:
# enter the string shubham
# length of string is 7

# %%
# extract username from a given email.
#eg if the email is shubham@001.com
#then the username should be shubham

s = input('enter the email')


pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email shubh@001.com
# shubh

# %%
"""Count the frequancy of a particular charachter in a provided string 
eg.. 'hello how are you'  is the string , the frequancy of h in this string is 2"""

s = input("enter the email")
term = input("what would like to search for")

counter = 0
for i in s:
    if i == term:
        counter += 1
print("frequancy", counter)
# Out:
# enter the email shubham001@.com
# what would like to search for 1
# frequancy 1

# %%
#write a program that can check whether a given string is palindrome or not

s = input('enter the string')

term = input('what would like to remove')

result = ''

for i in s:
    if i != term:
        result = result + i
print(result)
# Out:
# enter the string shubham
# what would like to remove u
# shbham

# %%
# write a program that can check whether a given string is palindrome or not
#abba
#malayalam
s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
    if s[i] !=[len(s) - i -1]:
        flag = False
        print("not a palindrome")
        break
if flag :
    print("palindrome")
# Out:
# enter the string abha
# not a palindrome

# %%
# write a program to count the number of words in a string without split()

###" hi how are you".split()


s = input("enter the string:")
L = []
temp = ''

for i in s:
    if i != ' ':
        temp = temp + i
    else:
        L.append(temp)
        temp = ''
L.append(temp)
print(L)
# Out:
# enter the string: hi how are you
# ['hi', 'how', 'are', 'you']

# %%
#write a python program to convert a string to title case without using the title()
s = input('enter the string:')
L = []
for i in s.split():
    L.append(i[0].upper() + i[1:].lower())
print(" ".join(L))
# Out:
# enter the string: hi i am shuBham
# Hi I Am Shubham

# %%
#write a program that can convert an int to string:

number  = int(input("enter the number"))

digits = '0123456789'
result = ''
while number != 0:
    result = digits[number % 10] + result

    number = number// 10
print(type(result))
# Out:
# enter the number 345
# <class 'str'>
