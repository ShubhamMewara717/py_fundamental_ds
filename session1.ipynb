# %% [markdown]
# Python Output

# %%
print("hello world")
# Out:
# hello world

# %%
print(90)
# Out:
# 90

# %%
print(True)
# Out:
# True

# %%
print("hello", 1, 9.8,True)
# Out:
# hello 1 9.8 True

# %%
print('hello', 1, 2.9, True, sep=' ')
# Out:
# hello 1 2.9 True

# %%
print('hello', end="-")
print('world')
# Out:
# hello-world

# %% [markdown]
# Data Types

# %%
#integer
print(8)
print(1e99)
# Out:
# 8
# 1e+99

# %%
#decimal
print(8.55)
# Out:
# 8.55

# %%
print(1.e99900)
# Out:
# inf

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#text string
print("hello world")
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({"name":'nitish'})
# Out:
# {'name': 'nitish'}

# %%
#type
(type("shubham"))
# Out:
# str

# %% [markdown]
# variable

# %%
#decimal 
name = "shubham"
print(name)



#static n
a = 6
b = 3
print(a + b)
# Out:
# shubham
# 9

# %%
#dynamic typing
a = 6

#static typing
int  = 5

# %%
#dynamic binding
a = 5
print(a)
a = 'shubham'
print(a)



#static binding
int  = 5
# Out:
# 5
# shubham

# %%
a=b=c= 9
print(a,b,c)



a, b , c = 1, 2, 3
print (a + b + c)
# Out:
# 9 9 9
# 6

# %% [markdown]
# Comments

# %%
# comment are use to define with hash(#)

# %% [markdown]
# Keywords & Identifiers

# %%
#keywords are 32 type they will not use as a variable


#identifiers
name = 'shubham'
print(name)
#you can,t start with a digit 
#you can use special chars -->
#idetifiers can not be keyword
# Out:
# shubham

# %% [markdown]
# user input

# %%
del int

# %%
print(int)
# Out:
# <class 'int'>

# %%
number1 = int(input("enter first number"))
#print(type(number1))

num2 = int(input("enter second number: "))
#print(type(num2))

result = (number1) + (num2)
print(result)
# Out:
# 13

# %% [markdown]
# TYPE Conversion

# %%
print(5+5.6)
print(type(5), type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#explicit
#str -> int
type(int('4'))
type(('4.5'))
# Out:
# str

# %% [markdown]
# Literals

# %%
a = 0b1010  #binary
b = 100  #decimal
c = 0o310 # octal
d = 0x12c # hexadecimal


#float 

float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5e-3

#complex 
x = 3.14j

print(a ,b ,c ,d)
# Out:
# 10 100 200 300

# %%
print(float_1 , float_2 , float_3)
# Out:
# 10.5 150.0 0.0015

# %%
print(x.imag)
print(x.real)
# Out:
# 3.14
# 0.0

# %%
a = True + 5 # true=1
b = False + 10 # false=0

print("a:", a)
print("b:", b)
# Out:
# a: 6
# b: 10

# %%
a = None
print(a)
# Out:
# None
